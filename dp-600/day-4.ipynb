# %%
import sys
sys.path.append('./../utils')
import ai

# %% [markdown]
# # Get started with Real-Time Intelligence with Microsoft Fabric
#
# https://aka.ms/fabric-real-time

# %%
# %%question
# What is Real-Time Intelligence?
# Out:
# **Real-Time Intelligence** refers to the ability to process and analyze data **instantly** as it is collected. This allows for **immediate insights** and decision-making, often used in applications like **fraud detection**, **security monitoring**, and **dynamic pricing**.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%question
# What is the Kusto Query Language (KQL)?
# Out:
# The **Kusto Query Language (KQL)** is a **query language** used to retrieve and analyze large datasets, primarily within **Azure Data Explorer** and **Log Analytics**. It is designed for **fast, interactive** queries and supports **filtering, aggregation, and visualization** of data.
