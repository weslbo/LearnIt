# %%
import sys
sys.path.append('./utils')
import ai

# %%
# %%question
# Who is eddy wally?

# %%
# %%question
# When did he die?

# %%
# %%audio
# Who is Eddy Merckx?
# Out:
# Eddy Merckx is a famous Belgian cyclist who is often considered one of the greatest in the history of the sport. He was incredibly successful during the late 1960s and 1970s, winning major races like the Tour de France and the Giro d'Italia multiple times. His exceptional endurance and versatile skills earned him the nickname "The Cannibal" because he was known for his relentless drive to win.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <video controls="" autoplay="" name="media">
#     <source src="audio\2025-01-09_13-33.mp4" type="audio/mp3">
# </video>

# %%
# %%audio
# Is he still alive?

# %%
# %%question
# Generate a table comparing iPod with iPhone

# %%
# %%video
# What is the end of the movie "Inception"?
