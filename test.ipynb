# %%
import sys
sys.path.append('./utils')
import ai

# %%
# %%question
# Who is eddy wally?

# %%
# %%question
# When did he die?

# %%
# %%audio
# Who is Eddy Merckx?
# Out:
# Eddy Merckx is a retired Belgian professional **cyclist**, widely regarded as one of the greatest cyclists of all time. He had an illustrious career during the 1960s and 1970s, winning numerous prestigious races, including the **Tour de France** five times and the **Giro d'Italia** five times. Known for his fierce competitiveness and versatility, Merckx earned the nickname "The Cannibal" for his relentless pursuit of victory.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%audio
# Is he still alive?

# %%
# %%question
# Generate a table comparing iPod with iPhone

# %%
# %%video
# What is the end of the movie "Inception"?
