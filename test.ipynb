# %%
import sys
sys.path.append('./utils')
import ai

# %%
# %%question
# Who is eddy wally?
# Out:
# Eddy Wally was a Belgian singer known for his flamboyant style and catchy pop songs. He gained popularity in the 1960s and 1970s, especially with the hit song "Chérie." He was also recognized for his extravagant personality and became a cultural icon in Belgium.

# %%
# %%question
# When did he die?
# Out:
# Eddy Wally died on February 6, 2016.

# %%
# %%audio
# Who is Eddy Merckx?
# Out:
# Eddy Merckx is a retired Belgian professional cyclist widely regarded as one of the greatest cyclists of all time. He dominated the sport during the late 1960s and 1970s, winning numerous prestigious races, including the Tour de France and Giro d'Italia multiple times. Known for his aggressive racing style and incredible endurance, Merckx earned the nickname "The Cannibal" for his relentless pursuit of victory in every race he entered.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%audio
# Is he still alive?

# %%
# %%question
# Generate a table comparing iPod with iPhone
