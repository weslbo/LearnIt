# %%
import sys
sys.path.append('./utils')
import ai

# %%
# %%question
# Who is eddy wally?

# %%
# %%question
# When did he die?

# %%
# %%audio
# Who is Eddy Merckx?
# Out:
# Eddy Merckx is a **legendary Belgian cyclist**, widely regarded as one of the greatest cyclists of all time. He dominated professional cycling in the late 1960s and 1970s, winning numerous prestigious races, including the Tour de France and Giro d'Italia multiple times. Known for his incredible endurance and versatility, Merckx earned the nickname "The Cannibal" for his relentless competitive spirit.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <video controls src="audio/2025-01-09_11-53.mp4" title="Title"></video>

# %%
# %%audio
# Is he still alive?

# %%
# %%question
# Generate a table comparing iPod with iPhone

# %%
# %%video
# What is the end of the movie "Inception"?
