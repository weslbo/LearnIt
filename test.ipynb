# %%
import sys
sys.path.append('./utils')
import ai

# %%
# %%question
# Who is eddy wally?

# %%
# %%question
# When did he die?

# %%
# %%audio
# Who is Eddy Merckx?
# Out:
# Eddy Merckx is a legendary cyclist from Belgium, considered one of the greatest in the history of the sport. He was incredibly successful in the late 1960s and 1970s, winning many major cycling races like the Tour de France and the Giro d'Italia several times. Known for his remarkable endurance and versatility, he earned the nickname "The Cannibal" because of his fierce competitiveness and desire to win.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%audio
# Is he still alive?

# %%
# %%question
# Generate a table comparing iPod with iPhone

# %%
# %%video
# What is the end of the movie "Inception"?
